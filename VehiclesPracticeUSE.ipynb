# %%
import pandas as pd

# https://www.youtube.com/watch?v=Z9dGmL2G-4k&list=PL2zq7klxX5ATPC8RuqCuTDdki3b4NqKQv

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv('vehicles.csv')

# %%
data.shape
# Out:
# (539759, 25)

# %%
data.head()
# Out:
#            id                                                url      region  \
# 0  7088746062  https://greensboro.craigslist.org/ctd/d/cary-2...  greensboro
# 1  7088745301  https://greensboro.craigslist.org/ctd/d/bmw-3-...  greensboro
# 2  7088744126  https://greensboro.craigslist.org/cto/d/greens...  greensboro
# 3  7088743681  https://greensboro.craigslist.org/ctd/d/cary-2...  greensboro
# 4  7074612539  https://lincoln.craigslist.org/ctd/d/gretna-20...     lincoln
#
#                           region_url  price    year manufacturer  \
# 0  https://greensboro.craigslist.org  10299  2012.0        acura
# 1  https://greensboro.craigslist.org      0  2011.0          bmw
# 2  https://greensboro.craigslist.org   9500  2011.0       jaguar
# 3  https://greensboro.craigslist.org   3995  2004.0        honda
# 4     https://lincoln.craigslist.org  41988  2016.0    chevrolet
#
#                model  condition    cylinders  ... drive  size         type  \
# ...

# %%
sns.distplot(data['year'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-ca730f829ce3> in <module>
# ----> 1 sns.distplot(data['year'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in _freedman_diaconis_bins(a)
#      37         return int(np.sqrt(a.size))
#      38     else:
# ---> 39         return int(np.ceil((a.max() - a.min()) / h))
#      40
#      41
#
# ValueError: cannot convert float NaN to integer

# %%
data['year'].plot(kind='hist')

# %%
# Make a HIST with amount of vehicles by year
data['year'].plot(kind='hist',bins=50,range=(1900, 2020))

# %%
# ORRRR
data['year'].plot.hist(bins=50,range=(1900, 2020))
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
data['type'].value_counts()
# Out:
# sedan          96119
# SUV            94626
# pickup         55934
# truck          50419
# coupe          21664
# other          18351
# hatchback      14791
# wagon          12194
# van            11006
# convertible     9089
# mini-van        6685
# offroad          835
# bus              577
# Name: type, dtype: int64

# %%
data['type'].value_counts().plot(kind='bar')

# %%
data[0:10]
# Out:
#            id                                                url      region  \
# 0  7088746062  https://greensboro.craigslist.org/ctd/d/cary-2...  greensboro
# 1  7088745301  https://greensboro.craigslist.org/ctd/d/bmw-3-...  greensboro
# 2  7088744126  https://greensboro.craigslist.org/cto/d/greens...  greensboro
# 3  7088743681  https://greensboro.craigslist.org/ctd/d/cary-2...  greensboro
# 4  7074612539  https://lincoln.craigslist.org/ctd/d/gretna-20...     lincoln
# 5  7088741557  https://greensboro.craigslist.org/ctd/d/cary-2...  greensboro
# 6  7088741418  https://greensboro.craigslist.org/ctd/d/cary-2...  greensboro
# 7  7088739008  https://greensboro.craigslist.org/ctd/d/cary-2...  greensboro
# 8  7088737004  https://greensboro.craigslist.org/ctd/d/cary-2...  greensboro
# 9  7088734576  https://greensboro.craigslist.org/ctd/d/cary-2...  greensboro
#
#                           region_url  price    year manufacturer  \
# ...

# %%
filter price > 5k and age <= 10

# %%
data[data['price']>5000]
# Out:
#                 id                                                url  \
# 0       7088746062  https://greensboro.craigslist.org/ctd/d/cary-2...
# 2       7088744126  https://greensboro.craigslist.org/cto/d/greens...
# 4       7074612539  https://lincoln.craigslist.org/ctd/d/gretna-20...
# 5       7088741557  https://greensboro.craigslist.org/ctd/d/cary-2...
# 6       7088741418  https://greensboro.craigslist.org/ctd/d/cary-2...
# ...            ...                                                ...
# 539754  7076296329  https://syracuse.craigslist.org/cto/d/mottvill...
# 539755  7088752165  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539756  7088749883  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539757  7088747986  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539758  7082122917  https://stcloud.craigslist.org/ctd/d/wadena-20...
#
#             region                         region_url  price    year  \
# ...

# %%
data['price']>5000
# Out:
# 0          True
# 1         False
# 2          True
# 3         False
# 4          True
#           ...
# 539754     True
# 539755     True
# 539756     True
# 539757     True
# 539758     True
# Name: price, Length: 539759, dtype: bool

# %%
#.  data[data['price']>5000]
data[() | ()]

# %%
data[(data['year'] >= 2010) | (data['price'] > 5000)]
# Out:
#                 id                                                url  \
# 0       7088746062  https://greensboro.craigslist.org/ctd/d/cary-2...
# 1       7088745301  https://greensboro.craigslist.org/ctd/d/bmw-3-...
# 2       7088744126  https://greensboro.craigslist.org/cto/d/greens...
# 4       7074612539  https://lincoln.craigslist.org/ctd/d/gretna-20...
# 5       7088741557  https://greensboro.craigslist.org/ctd/d/cary-2...
# ...            ...                                                ...
# 539754  7076296329  https://syracuse.craigslist.org/cto/d/mottvill...
# 539755  7088752165  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539756  7088749883  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539757  7088747986  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539758  7082122917  https://stcloud.craigslist.org/ctd/d/wadena-20...
#
#             region                         region_url  price    year  \
# ...

# %%
#OR
data.loc[(data['year'] >= 2010) | (data['price'] > 5000)]
# Out:
#                 id                                                url  \
# 0       7088746062  https://greensboro.craigslist.org/ctd/d/cary-2...
# 1       7088745301  https://greensboro.craigslist.org/ctd/d/bmw-3-...
# 2       7088744126  https://greensboro.craigslist.org/cto/d/greens...
# 4       7074612539  https://lincoln.craigslist.org/ctd/d/gretna-20...
# 5       7088741557  https://greensboro.craigslist.org/ctd/d/cary-2...
# ...            ...                                                ...
# 539754  7076296329  https://syracuse.craigslist.org/cto/d/mottvill...
# 539755  7088752165  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539756  7088749883  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539757  7088747986  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539758  7082122917  https://stcloud.craigslist.org/ctd/d/wadena-20...
#
#             region                         region_url  price    year  \
# ...

# %%
# Make new column PRICE2X

def price2x(price):
    return price*2

# %%
data['Price2'] = data['price'].apply(price2x)

# %%
data.head()
# Out:
#            id                                                url      region  \
# 0  7088746062  https://greensboro.craigslist.org/ctd/d/cary-2...  greensboro
# 1  7088745301  https://greensboro.craigslist.org/ctd/d/bmw-3-...  greensboro
# 2  7088744126  https://greensboro.craigslist.org/cto/d/greens...  greensboro
# 3  7088743681  https://greensboro.craigslist.org/ctd/d/cary-2...  greensboro
# 4  7074612539  https://lincoln.craigslist.org/ctd/d/gretna-20...     lincoln
#
#                           region_url  price    year manufacturer  \
# 0  https://greensboro.craigslist.org  10299  2012.0        acura
# 1  https://greensboro.craigslist.org      0  2011.0          bmw
# 2  https://greensboro.craigslist.org   9500  2011.0       jaguar
# 3  https://greensboro.craigslist.org   3995  2004.0        honda
# 4     https://lincoln.craigslist.org  41988  2016.0    chevrolet
#
#                model  condition    cylinders  ... size         type  \
# ...

# %%
# ALT way
data['price3'] = data['price'].apply(lambda x: x*3)
data.head()
# Out:
#            id                                                url      region  \
# 0  7088746062  https://greensboro.craigslist.org/ctd/d/cary-2...  greensboro
# 1  7088745301  https://greensboro.craigslist.org/ctd/d/bmw-3-...  greensboro
# 2  7088744126  https://greensboro.craigslist.org/cto/d/greens...  greensboro
# 3  7088743681  https://greensboro.craigslist.org/ctd/d/cary-2...  greensboro
# 4  7074612539  https://lincoln.craigslist.org/ctd/d/gretna-20...     lincoln
#
#                           region_url  price    year manufacturer  \
# 0  https://greensboro.craigslist.org  10299  2012.0        acura
# 1  https://greensboro.craigslist.org      0  2011.0          bmw
# 2  https://greensboro.craigslist.org   9500  2011.0       jaguar
# 3  https://greensboro.craigslist.org   3995  2004.0        honda
# 4     https://lincoln.craigslist.org  41988  2016.0    chevrolet
#
#                model  condition    cylinders  ...         type  paint_color  \
# ...

# %%
# MAke new column for expensive or cheap. expensive if price> 10k

# %%
data['isexpensive'] = data['price'].apply(lambda x: 'expensive' if x>10000 else 'cheap')
data.head()
# Out:
#            id                                                url      region  \
# 0  7088746062  https://greensboro.craigslist.org/ctd/d/cary-2...  greensboro
# 1  7088745301  https://greensboro.craigslist.org/ctd/d/bmw-3-...  greensboro
# 2  7088744126  https://greensboro.craigslist.org/cto/d/greens...  greensboro
# 3  7088743681  https://greensboro.craigslist.org/ctd/d/cary-2...  greensboro
# 4  7074612539  https://lincoln.craigslist.org/ctd/d/gretna-20...     lincoln
#
#                           region_url  price    year manufacturer  \
# 0  https://greensboro.craigslist.org  10299  2012.0        acura
# 1  https://greensboro.craigslist.org      0  2011.0          bmw
# 2  https://greensboro.craigslist.org   9500  2011.0       jaguar
# 3  https://greensboro.craigslist.org   3995  2004.0        honda
# 4     https://lincoln.craigslist.org  41988  2016.0    chevrolet
#
#                model  condition    cylinders  ... paint_color  \
# ...

# %%
data['isexpensive'].value_counts()
# Out:
# cheap        286551
# expensive    253208
# Name: isexpensive, dtype: int64

# %%
# Make new column for age<10 yrs old and price<10000
#data[() | ()]
#data['newandcheap'] = 
data[(data['year']>2010) | (data['price']<10000)]
# Out:
#                 id                                                url  \
# 0       7088746062  https://greensboro.craigslist.org/ctd/d/cary-2...
# 1       7088745301  https://greensboro.craigslist.org/ctd/d/bmw-3-...
# 2       7088744126  https://greensboro.craigslist.org/cto/d/greens...
# 3       7088743681  https://greensboro.craigslist.org/ctd/d/cary-2...
# 4       7074612539  https://lincoln.craigslist.org/ctd/d/gretna-20...
# ...            ...                                                ...
# 539753  7088754084  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539754  7076296329  https://syracuse.craigslist.org/cto/d/mottvill...
# 539755  7088752165  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539757  7088747986  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539758  7082122917  https://stcloud.craigslist.org/ctd/d/wadena-20...
#
#             region                         region_url  price    year  \
# ...

# %%
data['newandcheap'] = data[(data['year']>2010) | (data['price']<10000)]
